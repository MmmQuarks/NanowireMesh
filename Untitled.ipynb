# %%
import skimage
import numpy as np
from pathlib import Path
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv(
    Path(
		Path().cwd(), '2023-03-31_AdamAgNW', 'NanowireDataIndex.csv'
	)
)
df = df[(df.Slide == '3T') & (df.Sample == '02')]
df
# Out:
#      Data Date Slide Sample Slide / Sample        Slide / Sample / Type  \
# 16  2023-04-03    3T     02        3T / 02  3T / 02 / After Image Close
# 17  2023-04-03    3T     02        3T / 02  3T / 02 / After Image Close
# 44  2023-04-03    3T     02        3T / 02   3T / 02 / After Image Wide
# 67  2023-03-31    3T     02        3T / 02  3T / 02 / Before Image Wide
# 91  2023-03-31    3T     02        3T / 02               3T / 02 / Data
# 92  2023-03-31    3T     02        3T / 02               3T / 02 / Data
#
#                 Original Name  \
# 16  InLensSample3T_S02_58.tif
# 17  InLensSample3T_S02_59.tif
# 44  InLensSample3T_S02_57.tif
# 67        Sample3T_S02_18.tif
# 91         Sample3T-S02_1.txt
# 92         Sample3T-S02_2.txt
#
#                                         Relative Path               Type  \
# 16  2023-03-31_AdamAgNW/Post-test images/InLensSam...  After Image Close
# 17  2023-03-31_AdamAgNW/Post-test images/InLensSam...  After Image Close
# ...
